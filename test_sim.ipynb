# %%
from marketsim.simulator.sampled_arrival_simulator import SimulatorSampledArrival
from tqdm.notebook import tqdm

# %%
# %%timeit
# 
# sim = Simulator(num_agents=66, sim_time=60000, lam=1e-4, mean=1e7, r=.05, shock_var=1e6)
# sim.run()

# %%
# %%time
surpluses = []

for _ in tqdm(range(10000)):
    sim = SimulatorSampledArrival(num_background_agents=25, 
                                  sim_time=12000, 
                                  lam=5e-4, 
                                  mean=1e5, 
                                  r=0.05, 
                                  shock_var=5e6, 
                                  q_max=10,
                                  pv_var=5e6,
                                  shade=[250,500])
    sim.run()
    fundamental_val = sim.markets[0].get_final_fundamental()
    values = []
    for agent_id in sim.agents:
        agent = sim.agents[agent_id]
        value = agent.get_pos_value() + agent.position * fundamental_val + agent.cash
        # print(agent.cash, agent.position, agent.get_pos_value(), value)
        values.append(value)
    surpluses.append(sum(values)/len(values))
print(sum(surpluses)/len(surpluses)*25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~\PycharmProjects\pythonProject5\Daedalus\lib\site-packages\tqdm\notebook.py:103, in tqdm_notebook.status_printer(_, total, desc, ncols)
#     102 if total:
# --> 103     pbar = IntProgress(min=0, max=total)
#     104 else:  # No total? Show info style bar with no progress tqdm status
#
# NameError: name 'IntProgress' is not defined
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# File <timed exec>:3
#
# File ~\PycharmProjects\pythonProject5\Daedalus\lib\site-packages\tqdm\notebook.py:212, in tqdm_notebook.__init__(self, *args, **kwargs)
#     210 unit_scale = 1 if self.unit_scale is True else self.unit_scale or 1
#     211 total = self.total * unit_scale if self.total else self.total
# --> 212 self.container = self.status_printer(
#     213     self.fp, total, self.desc, self.ncols)
#     214 self.sp = self.display
#     216 # Print initial bar state
#
# File ~\PycharmProjects\pythonProject5\Daedalus\lib\site-packages\tqdm\notebook.py:110, in tqdm_notebook.status_printer(_, total, desc, ncols)
#     107         pbar.bar_style = 'info'
#     108 except NameError:
#     109     # #187 #451 #558
# --> 110     raise ImportError(
#     111         "IntProgress not found. Please update jupyter and ipywidgets."
#     112         " See https://ipywidgets.readthedocs.io/en/stable"
#     113         "/user_install.html")
#     115 if desc:
#     116     pbar.description = desc
#
# ImportError: IntProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %%
# %%time
surpluses = []

for _ in tqdm(range(10000)):
    sim = SimulatorSampledArrival(num_background_agents=25, 
                                  sim_time=24000, 
                                  lam=5e-4, 
                                  mean=1e5, 
                                  r=0.05, 
                                  shock_var=1e6, 
                                  q_max=10,
                                  pv_var=5e6,
                                  shade=[250,500])
    sim.run()
    fundamental_val = sim.markets[0].get_final_fundamental()
    values = []
    for agent_id in sim.agents:
        agent = sim.agents[agent_id]
        value = agent.get_pos_value() + agent.position * fundamental_val + agent.cash
        # print(agent.cash, agent.position, agent.get_pos_value(), value)
        values.append(value)
    surpluses.append(sum(values)/len(values))
print(sum(surpluses)/len(surpluses)*25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~\PycharmProjects\pythonProject5\Daedalus\lib\site-packages\tqdm\notebook.py:103, in tqdm_notebook.status_printer(_, total, desc, ncols)
#     102 if total:
# --> 103     pbar = IntProgress(min=0, max=total)
#     104 else:  # No total? Show info style bar with no progress tqdm status
#
# NameError: name 'IntProgress' is not defined
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# File <timed exec>:3
#
# File ~\PycharmProjects\pythonProject5\Daedalus\lib\site-packages\tqdm\notebook.py:212, in tqdm_notebook.__init__(self, *args, **kwargs)
#     210 unit_scale = 1 if self.unit_scale is True else self.unit_scale or 1
#     211 total = self.total * unit_scale if self.total else self.total
# --> 212 self.container = self.status_printer(
#     213     self.fp, total, self.desc, self.ncols)
#     214 self.sp = self.display
#     216 # Print initial bar state
#
# File ~\PycharmProjects\pythonProject5\Daedalus\lib\site-packages\tqdm\notebook.py:110, in tqdm_notebook.status_printer(_, total, desc, ncols)
#     107         pbar.bar_style = 'info'
#     108 except NameError:
#     109     # #187 #451 #558
# --> 110     raise ImportError(
#     111         "IntProgress not found. Please update jupyter and ipywidgets."
#     112         " See https://ipywidgets.readthedocs.io/en/stable"
#     113         "/user_install.html")
#     115 if desc:
#     116     pbar.description = desc
#
# ImportError: IntProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %%
# %%time
surpluses = []

for _ in tqdm(range(10000)):
    sim = SimulatorSampledArrival(num_background_agents=25, 
                                  sim_time=1000, 
                                  lam=5e-3, 
                                  mean=1e5, 
                                  r=0.05, 
                                  shock_var=5e5, 
                                  q_max=10,
                                  pv_var=5e6,
                                  shade=[250,500])
    sim.run()
    fundamental_val = sim.markets[0].get_final_fundamental()
    values = []
    for agent_id in sim.agents:
        agent = sim.agents[agent_id]
        value = agent.get_pos_value() + agent.position * fundamental_val + agent.cash
        # print(agent.cash, agent.position, agent.get_pos_value(), value)
        values.append(value)
    surpluses.append(sum(values)/len(values))
print(sum(surpluses)/len(surpluses)*25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~\PycharmProjects\pythonProject5\Daedalus\lib\site-packages\tqdm\notebook.py:103, in tqdm_notebook.status_printer(_, total, desc, ncols)
#     102 if total:
# --> 103     pbar = IntProgress(min=0, max=total)
#     104 else:  # No total? Show info style bar with no progress tqdm status
#
# NameError: name 'IntProgress' is not defined
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# File <timed exec>:3
#
# File ~\PycharmProjects\pythonProject5\Daedalus\lib\site-packages\tqdm\notebook.py:212, in tqdm_notebook.__init__(self, *args, **kwargs)
#     210 unit_scale = 1 if self.unit_scale is True else self.unit_scale or 1
#     211 total = self.total * unit_scale if self.total else self.total
# --> 212 self.container = self.status_printer(
#     213     self.fp, total, self.desc, self.ncols)
#     214 self.sp = self.display
#     216 # Print initial bar state
#
# File ~\PycharmProjects\pythonProject5\Daedalus\lib\site-packages\tqdm\notebook.py:110, in tqdm_notebook.status_printer(_, total, desc, ncols)
#     107         pbar.bar_style = 'info'
#     108 except NameError:
#     109     # #187 #451 #558
# --> 110     raise ImportError(
#     111         "IntProgress not found. Please update jupyter and ipywidgets."
#     112         " See https://ipywidgets.readthedocs.io/en/stable"
#     113         "/user_install.html")
#     115 if desc:
#     116     pbar.description = desc
#
# ImportError: IntProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %%
sim = SimulatorSampledArrival(num_background_agents=25, 
                              sim_time=1000, 
                              lam=5e-3, 
                              mean=1e5, 
                              r=0.05, 
                              shock_var=5e5, 
                              q_max=10,
                              pv_var=5e6,
                              shade=[250,500])
sim.run()
fundamental_val = sim.markets[0].get_final_fundamental()
values = []
for agent_id in sim.agents:
    agent = sim.agents[agent_id]
    value = agent.get_pos_value() + agent.position * fundamental_val + agent.cash
    # print(agent.cash, agent.position, agent.get_pos_value(), value)
    values.append(value)
surpluses.append(sum(values)/len(values))


positions = []
values = []
fundamental_val = sim.markets[0].get_final_fundamental()

for agent_id in sim.agents:
    agent = sim.agents[agent_id]
    value = agent.get_pos_value() + agent.position * fundamental_val + agent.cash
    # print(agent.cash, agent.position, agent.get_pos_value(), value)
    positions.append(agent.position)
    values.append(value)

import matplotlib.pyplot as plt

print(fundamental_val)
plt.scatter(positions, values)
plt.xlabel('Position')
plt.ylabel('Value')
plt.title(f'Agent Position vs Value at fundamental {fundamental_val}')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 10
#       1 sim = SimulatorSampledArrival(num_background_agents=25,
#       2                               sim_time=1000,
#       3                               lam=5e-3,
#    (...)
#       8                               pv_var=5e6,
#       9                               shade=[250,500])
# ---> 10 sim.run()
#      11 fundamental_val = sim.markets[0].get_final_fundamental()
#      12 values = []
#
# File C:\projects_AK\Daedalus\pymarketsim\marketsim\simulator\sampled_arrival_simulator.py:156, in SimulatorSampledArrival.run(self)
#     154 if self.arrivals[t]:
#     155     try:
# --> 156         self.step()
#     157     except KeyError:
#     158         print(self.arrivals[self.time])
#
# File C:\projects_AK\Daedalus\pymarketsim\marketsim\simulator\sampled_arrival_simulator.py:125, in SimulatorSampledArrival.step(self)
#     123 agent = self.agents[agent_id]
#     124 market.withdraw_all(agent_id)
# --> 125 orders = agent.take_action(estimate=cached_estimate)
#     126 market.add_orders(orders)
#     127 if self.arrival_index == self.arrivals_sampled:
#
# File C:\projects_AK\Daedalus\pymarketsim\marketsim\agent\zero_intelligence_agent.py:69, in ZIAgent.take_action(self, estimate)
#      67 # Use counter for order ID (faster than random.randint)
#      68 self._order_counter += 1
# ---> 69 order_id = id_generator.next()
#      71 order = Order(
#      72     price=price,
#      73     quantity=1,
#    (...)
#      77     order_id=order_id
#      78 )
#      80 return [order]
#
# AttributeError: 'IdGenerator' object has no attribute 'next'

# %%
sim = SimulatorSampledArrival(num_background_agents=25, 
                              sim_time=1000, 
                              lam=5e-3, 
                              mean=1e5, 
                              r=0.05, 
                              shock_var=5e5, 
                              q_max=10,
                              pv_var=5e6,
                              shade=[250,500])
sim.run()
fundamental_val = sim.markets[0].get_final_fundamental()
values = []
for agent_id in sim.agents:
    agent = sim.agents[agent_id]
    value = agent.get_pos_value() + agent.position * fundamental_val + agent.cash
    # print(agent.cash, agent.position, agent.get_pos_value(), value)
    values.append(value)
surpluses.append(sum(values)/len(values))


positions = []
values = []
fundamental_val = sim.markets[0].get_final_fundamental()

for agent_id in sim.agents:
    agent = sim.agents[agent_id]
    value = agent.get_pos_value() + agent.position * fundamental_val + agent.cash
    # print(agent.cash, agent.position, agent.get_pos_value(), value)
    positions.append(agent.position)
    values.append(value)

import matplotlib.pyplot as plt

print(fundamental_val)
plt.scatter(positions, values)
plt.xlabel('Position')
plt.ylabel('Value')
plt.title(f'Agent Position vs Value at fundamental {fundamental_val}')
plt.show()

# %%
sim = SimulatorSampledArrival(num_background_agents=100, 
                              sim_time=1000, 
                              lam=5e-3, 
                              mean=1e5, 
                              r=0.05, 
                              shock_var=5e5, 
                              q_max=10,
                              pv_var=5e6,
                              shade=[250,500])
sim.run()
fundamental_val = sim.markets[0].get_final_fundamental()
values = []
for agent_id in sim.agents:
    agent = sim.agents[agent_id]
    value = agent.get_pos_value() + agent.position * fundamental_val + agent.cash
    # print(agent.cash, agent.position, agent.get_pos_value(), value)
    values.append(value)


positions = []
values = []
fundamental_val = sim.markets[0].get_final_fundamental()

for agent_id in sim.agents:
    agent = sim.agents[agent_id]
    value = agent.get_pos_value() + agent.position * fundamental_val + agent.cash
    # print(agent.cash, agent.position, agent.get_pos_value(), value)
    positions.append(agent.position)
    values.append(value)

import matplotlib.pyplot as plt

print(fundamental_val)
plt.scatter(positions, values)
plt.xlabel('Position')
plt.ylabel('Value')
plt.title(f'Agent Position vs Value at fundamental {fundamental_val}')
plt.show()
